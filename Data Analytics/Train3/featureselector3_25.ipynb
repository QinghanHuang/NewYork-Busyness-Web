# %%
import pandas as panda


from google.colab import drive
drive.mount('/content/drive')



df =   panda.read_csv('/content/drive/MyDrive/2018.22manhattenyellowtaxis.csv')
# Out:
# Mounted at /content/drive

# %%
df.dtypes
# Out:
# VendorID                   int64
# tpep_pickup_datetime      object
# tpep_dropoff_datetime     object
# passenger_count            int64
# trip_distance            float64
# RatecodeID                 int64
# store_and_fwd_flag        object
# PULocationID               int64
# DOLocationID               int64
# payment_type               int64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# improvement_surcharge    float64
# total_amount             float64
# dtype: object

# %%
for i in df:
    print(f"\ndifferent values   {i}:")
    print(df[i].unique())
# Out:
# different values   VendorID:
# [1 2 4]
#
# different values   tpep_pickup_datetime:
# ['2018-04-27 20:15:08' '2018-04-27 20:22:24' '2018-04-27 20:38:44' ...
#  '2018-04-27 20:46:23' '2018-04-27 20:49:55' '2018-04-27 20:33:32']
#
# different values   tpep_dropoff_datetime:
# ['2018-04-27 20:15:33' '2018-04-27 20:34:10' '2018-04-27 20:52:05' ...
#  '2018-04-27 20:33:06' '2018-04-27 20:59:24' '2018-04-27 20:37:16']
#
# different values   passenger_count:
# [1 2 3 5 6 4]
#
# different values   trip_distance:
# [0.   1.9  1.5  0.9  0.6  0.8  4.4  0.5  2.56 3.37 1.03 1.38 4.08 2.4
#  4.9  4.1  1.1  0.55 1.83 1.45 0.75 0.63 0.65 2.52 1.   1.7  0.18 1.6
#  0.59 1.85 1.34 0.91 1.13 1.62 2.11 1.4  2.1  3.   2.22 3.4  4.41 2.67
#  1.55 1.08 0.87 1.01 1.3  1.02 1.67 4.68 0.05 4.03 3.57 0.67 0.83 2.24
#  1.98 0.52 0.76 1.95 0.99 2.8  0.7  0.54 1.41 1.84 1.72 2.66 1.32 1.8
#  1.75 4.6  3.2  1.37 2.14 1.31 1.56 2.21 1.04 2.69 2.3  1.2  2.6  1.51
#  0.82 1.86 2.08 3.6  1.29 1.63 0.72 0.42 1.52 2.72 2.9  0.3  1.33 3.08
#  1.07 2.03 2.62 1.48 2.47 1.16 4.07 0.84 0.94 1.21 2.17 1.94 1.14 0.51
#  0.86 2.   0.95 3.27 0.64 0.92 1.35 1.27 1.11 1.15 0.61 0.89 2.91 2.01
#  1.28 1.09 1.25 2.59 1.54 4.   3.7  2.07 1.19 0.27 2.31 1.49 2.18 1.88
#  1.81 1.36 1.42 2.34 3.5  0.69 3.58 0.46 0.96 1.97 2.2  2.37 4.49 4.78
#  2.87 3.1  3.8  3.9  3.43 0.71 4.01 1.69 2.42 0.81 1.05 4.7  3.02 0.43
#  0.4  4.2  2.02 3.11 0.49 3.56 2.06 1.73 1.46 1.57 1.76 2.5  3.3  1.61
#  0.78 0.66 2.28 3.01 4.85 1.78 1.23 1.64 4.8  4.3  1.68 3.54 1.06 2.77
#  1.79 2.32 0.16 0.57 1.44 3.16 2.81 4.18 3.49 3.41 3.97 1.82 2.74 4.09
#  0.37 2.04 2.57 0.97 3.77 3.05 4.11 3.21 2.45 0.26 2.75 0.58 1.22 2.13
#  0.47 1.66 1.39 3.78 1.24 0.2  4.04 3.33 3.48 3.67 2.46 3.31 3.81 2.71
to_datetime(df['tpep_pickup_datetime'])
df['tpep_dropoff_datetime']  =   panda.to_datetime(df['tpep_dropoff_datetime'])

# %%
df = df.sort_values(by='tpep_dropoff_datetime')

# %%
print(df.dtypes)
# Out:
# VendorID                          int64
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                   int64
# trip_distance                   float64
# RatecodeID                        int64
# store_and_fwd_flag               object
# PULocationID                      int64
# DOLocationID                      int64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# dtype: object

# %%
cols1 = ['store_and_fwd_flag',  'mta_tax',  'improvement_surcharge',  'passenger_count',  'RatecodeID',    'payment_type',   'VendorID',
  'extra']

# %%
counts1 =    {col: df[col].value_counts().to_dict() for col in cols1}

# %%
counts1
# Out:
# {'store_and_fwd_flag': {'N': 90262091, 'Y': 386520},
#  'mta_tax': {0.5: 90547279, 0.0: 101332},
#  'improvement_surcharge': {0.3: 90640014, 0.0: 8597},
#  'passenger_count': {1: 65235485,
#   2: 13261264,
#   5: 4077137,
#   3: 3800949,
#   6: 2477148,
#   4: 1796628},
#  'RatecodeID': {1: 88907902, 2: 1572184, 5: 153985, 3: 11525, 4: 2583, 6: 432},
#  'payment_type': {1: 63278679, 2: 26850420, 3: 400264, 4: 119247, 5: 1},
#  'VendorID': {2: 52494125, 1: 37714270, 4: 440216},
#  'extra': {0.0: 49401585,
#   0.5: 25819216,
#   1.0: 15131459,
#   4.5: 292018,
#   0.8: 1280,
#   0.3: 933,
#   1.3: 771,
#   0.11: 379,
#   1.5: 314,
#   1.8: 241,
#   0.22: 201,
#   0.7: 23,
#   4.8: 21,
#   0.45: 18,
#   1.1: 17,
#   0.2: 17,
#   5.3: 12,
#   0.55: 10,
#   0.95: 8,
#   4.54: 7,
#   0.02: 6,
#   66.66: 6,
#   0.4: 5,
#   0.6: 5,
#   2.5: 4,
#   0.35: 4,
#   1.45: 4,
#   0.49: 3,
#   2.0: 3,
#   1.6: 3,
#   5.5: 2,
#   1.01: 2,
#   6.52: 2,
#   0.03: 2,
#   60.0: 2,
#   83.0: 1,
#   82.5: 1,
#   0.56: 1,
#   80.0: 1,
#   0.09: 1,
#   3.6: 1,
#   3.1: 1,
#   61.61: 1,
#   5.76: 1,
#   6.5: 1,
#   5.62: 1,
#   9.3: 1,
#   6.6: 1,
#   2.74: 1,
#   0.01: 1,
#   15.16: 1,
#   1.51: 1,
#   3.3: 1,
#   0.32: 1,
#   19.0: 1,
#   3.4: 1,
#   14.5: 1,
#   4.0: 1,
#   96.64: 1,
#   30.5: 1,
#   3.0: 1,
#   15.55: 1,
#   5.6: 1}}

# %%
df =   df.drop(columns=['store_and_fwd_flag',   'mta_tax',   'improvement_surcharge'])

# %%
cols2 = ['trip_distance',   'fare_amount',   'tip_amount',   'total_amount',   'tolls_amount',  'total_amount']

# get the levels of varience
var1 =  df[cols2].var()

# get the correlations of the features
corr1 =   df[cols2].corr()

var1,    corr1
# Out:
# (trip_distance     1.756978
#  fare_amount      28.276034
#  tip_amount        2.241945
#  total_amount     37.939488
#  tolls_amount      0.000000
#  total_amount     37.939488
#  dtype: float64,
#                 trip_distance  fare_amount  tip_amount  total_amount  \
#  trip_distance       1.000000     0.911117    0.488864      0.897350
#  fare_amount         0.911117     1.000000    0.523400      0.980122
#  tip_amount          0.488864     0.523400    1.000000      0.651915
#  total_amount        0.897350     0.980122    0.651915      1.000000
#  tolls_amount             NaN          NaN         NaN           NaN
#  total_amount        0.897350     0.980122    0.651915      1.000000
#
#                 tolls_amount  total_amount
#  trip_distance           NaN      0.897350
#  fare_amount             NaN      0.980122
#  tip_amount              NaN      0.651915
#  total_amount            NaN      1.000000
#  tolls_amount            NaN           NaN
#  total_amount            NaN      1.000000  )

# %%
# we will later conside dropping fare and total depending on the feature importance as correlated with trip_distance
#df = df.drop(columns=['fare_amount', 'total_amount'])
df =   df.drop(columns=[ 'tolls_amount'])

# %%
from sklearn.preprocessing import LabelEncoder

# make the encoder
labelencoder = LabelEncoder()

# new dataframe
df_encoded = df.copy()

# these are the categoical columns we are going to find the correlations for
cat_cols = ['RatecodeID', 'payment_type', 'VendorID']

# call the label encoder on these
for col in cat_cols:

    df_encoded[col] =   labelencoder.fit_transform(df_encoded[col])

# get the correlation matrix
corr_encoded =   df_encoded.corr()

# get the distribution aswell
cat_distribution =   {col: df[col].value_counts().to_dict() for col in cat_cols}

cat_distribution,    corr_encoded
# Out:
# <ipython-input-14-e6fe1ff031e8>:18: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_encoded =   df_encoded.corr()
# ({'RatecodeID': {1: 88907902,
#    2: 1572184,
#    5: 153985,
#    3: 11525,
#    4: 2583,
#    6: 432},
#   'payment_type': {1: 63278679, 2: 26850420, 3: 400264, 4: 119247, 5: 1},
#   'VendorID': {2: 52494125, 1: 37714270, 4: 440216}},
#                   VendorID  passenger_count  trip_distance  RatecodeID  \
#  VendorID         1.000000         0.228954       0.027364    0.017249
#  passenger_count  0.228954         1.000000       0.017424   -0.003152
#  trip_distance    0.027364         0.017424       1.000000    0.145235
#  RatecodeID       0.017249        -0.003152       0.145235    1.000000
#  PULocationID    -0.012152        -0.005428      -0.088380   -0.032396
#  DOLocationID    -0.004274        -0.003416      -0.054805   -0.008374
#  payment_type    -0.016677         0.012852      -0.087661   -0.004199
#  fare_amount      0.014977         0.012872       0.911117    0.234776
#  extra            0.002100         0.005657       0.056629    0.070558
#  tip_amount       0.005838        -0.007714       0.488864    0.136521
#  total_amount     0.014762         0.010192       0.897350    0.233098
#
#                   PULocationID  DOLocationID  payment_type  fare_amount  \
#  VendorID            -0.012152     -0.004274     -0.016677     0.014977
#  passenger_count     -0.005428     -0.003416      0.012852     0.012872
#  trip_distance       -0.088380     -0.054805     -0.087661     0.911117
#  RatecodeID          -0.032396     -0.008374     -0.004199     0.234776
#  PULocationID         1.000000      0.080184     -0.011171    -0.080710
#  DOLocationID         0.080184      1.000000     -0.020910    -0.046252
#  payment_type        -0.011171     -0.020910      1.000000    -0.079418
#  fare_amount         -0.080710     -0.046252     -0.079418     1.000000
#  extra               -0.015461     -0.010561     -0.022058     0.037793
#  tip_amount          -0.035352      0.000129     -0.656755     0.523400
#  total_amount        -0.077521     -0.041547     -0.211344     0.980122
#
#                      extra  tip_amount  total_amount
#  VendorID         0.002100    0.005838      0.014762
#  passenger_count  0.005657   -0.007714      0.010192
#  trip_distance    0.056629    0.488864      0.897350
#  RatecodeID       0.070558    0.136521      0.233098
#  PULocationID    -0.015461   -0.035352     -0.077521
#  DOLocationID    -0.010561    0.000129     -0.041547
#  payment_type    -0.022058   -0.656755     -0.211344
#  fare_amount      0.037793    0.523400      0.980122
#  extra            1.000000    0.061381      0.095902
#  tip_amount       0.061381    1.000000      0.651915
#  total_amount     0.095902    0.651915      1.000000  )

# %%
del df_encoded

# %%
# we will consider dopping these columns based on the feature importances after training the model.
#df = df.drop(columns=['extra', 'payment_type'])

# %%
df.dtypes
# Out:
# VendorID                          int64
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                   int64
# trip_distance                   float64
# RatecodeID                        int64
# PULocationID                      int64
# DOLocationID                      int64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# tip_amount                      float64
# total_amount                    float64
# dtype: object

# %%
print(len(df))
# Out:
# 90648611

# %%
# make new features
df['dropoff_hour'] =   df['tpep_dropoff_datetime'].dt.hour
df['dropoff_month'] =   df['tpep_dropoff_datetime'].dt.month

df['dropoff_day_of_month'] =   df['tpep_dropoff_datetime'].dt.day
df['dropoff_day_of_week'] =    df['tpep_dropoff_datetime'].dt.dayofweek




# make a feature that measures the journeys duration
df['ride_duration'] = (df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime']).dt.total_seconds() / 60

# get rid of extremely small values so they dont affect calculation for speed

df = df[df['ride_duration'] >= 1]


# Create the average speed feature (in mph)
df['average_speed'] = df['trip_distance'] / (df['ride_duration'] / 60)

df.head()
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 16664318         2  2018-01-01 00:00:40   2018-01-01 00:01:59
# 16659848         2  2018-01-01 00:00:59   2018-01-01 00:02:28
# 16658155         2  2018-01-01 00:01:22   2018-01-01 00:02:35
# 16667681         2  2018-01-01 00:02:18   2018-01-01 00:03:23
# 16668191         2  2018-01-01 00:00:36   2018-01-01 00:03:33
#
#           passenger_count  trip_distance  RatecodeID  PULocationID  \
# 16664318                1           0.50           1            68
# 16659848                1           0.40           1            13
# 16658155                1           0.47           1            74
# 16667681                1           0.19           1            43
# 16668191                1           0.70           1           237
#
#           DOLocationID  payment_type  fare_amount  extra  tip_amount  \
# 16664318           246             1          3.5    0.5        0.00
# 16659848            13             1          3.5    0.5        0.96
# 16658155            75             2          3.5    0.5        0.00
# 16667681           163             2          3.0    0.5        0.00
# 16668191           237             1          4.5    0.5        0.00
#
#           total_amount  dropoff_hour  dropoff_month  dropoff_day_of_month  \
# 16664318          4.80             0              1                     1
# 16659848          5.76             0              1                     1
# 16658155          4.80             0              1                     1
# 16667681          4.30             0              1                     1
# 16668191          5.80             0              1                     1
#
#           dropoff_day_of_week  ride_duration  average_speed
# 16664318                    0       1.316667      22.784810
# 16659848                    0       1.483333      16.179775
# 16658155                    0       1.216667      23.178082
# 16667681                    0       1.083333      10.523077
# 16668191                    0       2.950000      14.237288

# %%
import numpy as nump
mask =   nump.isfinite(df['average_speed'])
df =   df[mask]

# %%
# get the variance
v_ride_duration =   df['ride_duration'].var()
v_average_speed =    df['average_speed'].var()

# get a new correlation matrix
corr3 =   df[['ride_duration', 'average_speed', 'trip_distance', 'tip_amount', 'fare_amount', 'total_amount']].corr()

v_ride_duration,  v_average_speed,     corr3
# Out:
# (4210.561395646896,
#  18.178760758240582,
#                 ride_duration  average_speed  trip_distance  tip_amount  \
#  ride_duration       1.000000      -0.145069       0.128443    0.064167
#  average_speed      -0.145069       1.000000       0.258978   -0.001652
#  trip_distance       0.128443       0.258978       1.000000    0.493474
#  tip_amount          0.064167      -0.001652       0.493474    1.000000
#  fare_amount         0.151728      -0.040304       0.921303    0.522361
#  total_amount        0.145836      -0.032635       0.907522    0.651570
#
#                 fare_amount  total_amount
#  ride_duration     0.151728      0.145836
#  average_speed    -0.040304     -0.032635
#  trip_distance     0.921303      0.907522
#  tip_amount        0.522361      0.651570
#  fare_amount       1.000000      0.980204
#  total_amount      0.980204      1.000000  )

# %%
df2 = panda.read_csv('/content/drive/MyDrive/taxi_zones (1).csv')

# %%
# check if each location id has one area
the_unique_location_ids = df2['LocationID'].nunique()
unique_shape_areas = df2.groupby('LocationID')['Shape_Area'].nunique()

# find which ones have multiple areas
the_invalid_location_ids = unique_shape_areas[unique_shape_areas > 1].index.tolist()

# check if every location id is in df2
the_valid_dropoff_ids = df['DOLocationID'].isin(df2['LocationID']).all()

the_unique_location_ids,   the_invalid_location_ids,   the_valid_dropoff_ids
# Out:
# (260, [56, 103], True)

# %%
df =   df[~df['DOLocationID'].isin(the_invalid_location_ids)]

# %%
df2 =    df2[~df2['LocationID'].isin(the_invalid_location_ids)]

# %%
not_in_zones_pickup_ids = set(df['PULocationID'].unique()) - set(df2['LocationID'].unique())
not_in_zones_dropoff_ids = set(df['DOLocationID'].unique()) - set(df2['LocationID'].unique())

not_in_zones_pickup_ids,    not_in_zones_dropoff_ids
# Out:
# ({56, 57, 105, 264, 265}, set())

# %%
df =  df[~df['PULocationID'].isin(not_in_zones_pickup_ids)]
df =   df[~df['DOLocationID'].isin(not_in_zones_dropoff_ids)]

# %%
print(len(df))
# Out:
# 89920975

# %%
# map locationid to shape_area
location_to_area = df2.set_index('LocationID')['Shape_Area'].to_dict()

location_to_perimeter = df2.set_index('LocationID')['Shape_Leng'].to_dict()

# new feature in df for the area of a dropoff location
df['DOLocation_area'] = df['DOLocationID'].map(location_to_area)

df['DOLocation_perimeter'] = df['DOLocationID'].map(location_to_perimeter)

df.head()
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 16664318         2  2018-01-01 00:00:40   2018-01-01 00:01:59
# 16659848         2  2018-01-01 00:00:59   2018-01-01 00:02:28
# 16658155         2  2018-01-01 00:01:22   2018-01-01 00:02:35
# 16667681         2  2018-01-01 00:02:18   2018-01-01 00:03:23
# 16668191         2  2018-01-01 00:00:36   2018-01-01 00:03:33
#
#           passenger_count  trip_distance  RatecodeID  PULocationID  \
# 16664318                1           0.50           1            68
# 16659848                1           0.40           1            13
# 16658155                1           0.47           1            74
# 16667681                1           0.19           1            43
# 16668191                1           0.70           1           237
#
#           DOLocationID  payment_type  fare_amount  ...  tip_amount  \
# 16664318           246             1          3.5  ...        0.00
# 16659848            13             1          3.5  ...        0.96
# 16658155            75             2          3.5  ...        0.00
# 16667681           163             2          3.0  ...        0.00
# 16668191           237             1          4.5  ...        0.00
#
#           total_amount  dropoff_hour  dropoff_month  dropoff_day_of_month  \
# 16664318          4.80             0              1                     1
# 16659848          5.76             0              1                     1
# 16658155          4.80             0              1                     1
# 16667681          4.30             0              1                     1
# 16668191          5.80             0              1                     1
#
#           dropoff_day_of_week  ride_duration  average_speed  DOLocation_area  \
# 16664318                    0       1.316667      22.784810         0.000281
# 16659848                    0       1.483333      16.179775         0.000149
# 16658155                    0       1.216667      23.178082         0.000241
# 16667681                    0       1.083333      10.523077         0.000041
# 16668191                    0       2.950000      14.237288         0.000096
#
#           DOLocation_perimeter
# 16664318              0.069467
# 16659848              0.050281
# 16658155              0.087664
# 16667681              0.034177
# 16668191              0.042213
#
# [5 rows x 21 columns]

# %%
# make a feature rounded the datetime to the nearest hour
df['dropoff_datetime_hour'] = df['tpep_dropoff_datetime'].dt.floor('H')

# For dropoff
dropoff_counts_hourly = df.groupby(['DOLocationID', 'dropoff_datetime_hour']).size().reset_index(name='number_taxis_DOLocationID_for_this_hour')

# merge it
df = panda.merge(df, dropoff_counts_hourly, how='left', left_on=['DOLocationID', 'dropoff_datetime_hour'], right_on=['DOLocationID', 'dropoff_datetime_hour'])


df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2018-01-01 00:00:40   2018-01-01 00:01:59                1
# 1         2  2018-01-01 00:00:59   2018-01-01 00:02:28                1
# 2         2  2018-01-01 00:01:22   2018-01-01 00:02:35                1
# 3         2  2018-01-01 00:02:18   2018-01-01 00:03:23                1
# 4         2  2018-01-01 00:00:36   2018-01-01 00:03:33                1
#
#    trip_distance  RatecodeID  PULocationID  DOLocationID  payment_type  \
# 0           0.50           1            68           246             1
# 1           0.40           1            13            13             1
# 2           0.47           1            74            75             2
# 3           0.19           1            43           163             2
# 4           0.70           1           237           237             1
#
#    fare_amount  ...  dropoff_hour  dropoff_month  dropoff_day_of_month  \
# 0          3.5  ...             0              1                     1
# 1          3.5  ...             0              1                     1
# 2          3.5  ...             0              1                     1
# 3          3.0  ...             0              1                     1
# 4          4.5  ...             0              1                     1
#
#    dropoff_day_of_week  ride_duration  average_speed  DOLocation_area  \
# 0                    0       1.316667      22.784810         0.000281
# 1                    0       1.483333      16.179775         0.000149
# 2                    0       1.216667      23.178082         0.000241
# 3                    0       1.083333      10.523077         0.000041
# 4                    0       2.950000      14.237288         0.000096
#
#    DOLocation_perimeter  dropoff_datetime_hour  \
# 0              0.069467             2018-01-01
# 1              0.050281             2018-01-01
# 2              0.087664             2018-01-01
# 3              0.034177             2018-01-01
# 4              0.042213             2018-01-01
#
#    number_taxis_DOLocationID_for_this_hour
# 0                                      149
# 1                                       64
# 2                                      183
# 3                                       52
# 4                                      252
#
# [5 rows x 23 columns]

# %%
print(len(df))
# Out:
# 89920975

# %%
x = df['DOLocationID'].nunique()
x
# Out:
# 66

# %%
# aggregate the dataframe so that theres one row per hour for the prediction
aggs = {
    'VendorID': lambda x: x.mode()[0] if x.mode().size > 0 else None,
    'trip_distance': 'mean',
    'fare_amount': 'mean',
    'total_amount': 'mean',
    'extra': 'mean',
    'RatecodeID': lambda x: x.mode()[0] if x.mode().size > 0 else None,
    'payment_type': lambda x: x.mode()[0] if x.mode().size > 0 else None,
    'tip_amount': 'mean',

    'ride_duration': 'mean',
    'average_speed': 'mean',
    'dropoff_hour': 'first',
    'DOLocation_area': 'first',
    'DOLocation_perimeter': 'first',
    'number_taxis_DOLocationID_for_this_hour': 'first',
    'dropoff_day_of_week': 'first',
    'dropoff_day_of_month': 'first',
    'dropoff_month': 'first',
    'passenger_count': 'mean'
}

# make the aggregated dataframe next
df_aggregated = df.groupby(['dropoff_datetime_hour', 'DOLocationID']).agg(aggs).reset_index()

# Display a few rows
df_aggregated.head()
# Out:
#   dropoff_datetime_hour  DOLocationID  VendorID  trip_distance  fare_amount  \
# 0            2018-01-01             4         2       1.742100     9.237500
# 1            2018-01-01            12         1       3.366667    12.500000
# 2            2018-01-01            13         2       3.052656    13.390625
# 3            2018-01-01            24         2       2.115143     9.485714
# 4            2018-01-01            41         2       2.548800    11.327500
#
#    total_amount  extra  RatecodeID  payment_type  tip_amount  ride_duration  \
# 0     11.722200  0.495           1             1    1.209800      10.812167
# 1     15.600000  0.500           1             1    1.800000      12.772222
# 2     16.369844  0.500           1             1    1.710781      14.340625
# 3     12.281143  0.500           1             1    1.596143       9.520952
# 4     14.017950  0.485           1             1    1.435200      12.044333
#
#    average_speed  dropoff_hour  DOLocation_area  DOLocation_perimeter  \
# 0       9.950562             0         0.000112              0.043567
# 1      15.888399             0         0.000042              0.036661
# 2      12.741622             0         0.000149              0.050281
# 3      13.578451             0         0.000061              0.047000
# 4      12.852781             0         0.000143              0.052793
#
#    number_taxis_DOLocationID_for_this_hour  dropoff_day_of_week  \
# 0                                      100                    0
# 1                                        3                    0
# 2                                       64                    0
# 3                                       70                    0
# 4                                      100                    0
#
#    dropoff_day_of_month  dropoff_month  passenger_count
# 0                     1              1         1.680000
# 1                     1              1         1.000000
# 2                     1              1         1.812500
# 3                     1              1         1.742857
# 4                     1              1         1.700000

# %%
print(len(df_aggregated))
# Out:
# 554235

# %%
df_aggregated.dtypes
# Out:
# dropoff_datetime_hour                      datetime64[ns]
# DOLocationID                                        int64
# VendorID                                            int64
# trip_distance                                     float64
# fare_amount                                       float64
# total_amount                                      float64
# extra                                             float64
# RatecodeID                                          int64
# payment_type                                        int64
# tip_amount                                        float64
# ride_duration                                     float64
# average_speed                                     float64
# dropoff_hour                                        int64
# DOLocation_area                                   float64
# DOLocation_perimeter                              float64
# number_taxis_DOLocationID_for_this_hour             int64
# dropoff_day_of_week                                 int64
# dropoff_day_of_month                                int64
# dropoff_month                                       int64
# passenger_count                                   float64
# dtype: object

# %%
df_aggregated.to_csv('/content/drive/MyDrive/2018.31manhattenyellowtaxis.csv', index=False)
